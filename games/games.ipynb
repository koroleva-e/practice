# %% [markdown]
# # Исследование о продаже компьютерных игр

# %% [markdown]
# <h1>Навигация<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Открываем-файл-с-данными-и-изучаем-общую-информацию" data-toc-modified-id="Открываем-файл-с-данными-и-изучаем-общую-информацию-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Открываем файл с данными и изучаем общую информацию</a></span><ul class="toc-item"><li><span><a href="#Загрузим-данные-из-файла-в-датафрейм.-Выведем-первые-5-строк-на-экран" data-toc-modified-id="Загрузим-данные-из-файла-в-датафрейм.-Выведем-первые-5-строк-на-экран-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузим данные из файла в датафрейм. Выведем первые 5 строк на экран</a></span></li><li><span><a href="#Выведем-основную-информацию-о-датафрейме-с-помощью-метода-info()" data-toc-modified-id="Выведем-основную-информацию-о-датафрейме-с-помощью-метода-info()-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Выведем основную информацию о датафрейме с помощью метода info()</a></span></li><li><span><a href="#Смотрим-числовое-описание-данных" data-toc-modified-id="Смотрим-числовое-описание-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Смотрим числовое описание данных</a></span></li><li><span><a href="#Чтобы-увидеть-плотность-распределения-и-выбросы,-построим-общую-гистограмму-для-всех-числовых-столбцов-таблицы" data-toc-modified-id="Чтобы-увидеть-плотность-распределения-и-выбросы,-построим-общую-гистограмму-для-всех-числовых-столбцов-таблицы-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Чтобы увидеть плотность распределения и выбросы, построим общую гистограмму для всех числовых столбцов таблицы</a></span></li><li><span><a href="#Общий-вывод-после-изучения-данных" data-toc-modified-id="Общий-вывод-после-изучения-данных-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Общий вывод после изучения данных</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Найдем-и-изучим-пропущенные-значения-в-столбцах" data-toc-modified-id="Найдем-и-изучим-пропущенные-значения-в-столбцах-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Найдем и изучим пропущенные значения в столбцах</a></span></li><li><span><a href="#Заменим-названия-столбцов" data-toc-modified-id="Заменим-названия-столбцов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Заменим названия столбцов</a></span></li><li><span><a href="#Приведем-значения-к-нужному-типу-данных" data-toc-modified-id="Приведем-значения-к-нужному-типу-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Приведем значения к нужному типу данных</a></span><ul class="toc-item"><li><span><a href="#year_of_release-(float-👉-int)" data-toc-modified-id="year_of_release-(float-👉-int)-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span><code>year_of_release</code> (float 👉 int)</a></span></li></ul></li><li><span><a href="#Изучим-уникальные-значения-в-столбцах-и-устраним-дубликаты" data-toc-modified-id="Изучим-уникальные-значения-в-столбцах-и-устраним-дубликаты-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Изучим уникальные значения в столбцах и устраним дубликаты</a></span><ul class="toc-item"><li><span><a href="#name" data-toc-modified-id="name-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span><code>name</code></a></span></li><li><span><a href="#platform" data-toc-modified-id="platform-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span><code>platform</code></a></span></li><li><span><a href="#genre" data-toc-modified-id="genre-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span><code>genre</code></a></span></li><li><span><a href="#user_score" data-toc-modified-id="user_score-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span><code>user_score</code></a></span></li><li><span><a href="#rating" data-toc-modified-id="rating-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span><code>rating</code></a></span></li></ul></li><li><span><a href="#Cбросим-индексацию-после-удаления-строк-и-еще-раз-взглянем-на-данные" data-toc-modified-id="Cбросим-индексацию-после-удаления-строк-и-еще-раз-взглянем-на-данные-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Cбросим индексацию после удаления строк и еще раз взглянем на данные</a></span></li><li><span><a href="#Посчитаем-суммарные-продажи-во-всех-регионах-и-запишем-их-в-отдельный-столбец-general_sales" data-toc-modified-id="Посчитаем-суммарные-продажи-во-всех-регионах-и-запишем-их-в-отдельный-столбец-general_sales-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец <code>general_sales</code></a></span></li><li><span><a href="#Общий-вывод-после-предобработки-данных" data-toc-modified-id="Общий-вывод-после-предобработки-данных-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Общий вывод после предобработки данных</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Сколько-игр-выпускалось-в-разные-годы" data-toc-modified-id="Сколько-игр-выпускалось-в-разные-годы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Сколько игр выпускалось в разные годы</a></span></li><li><span><a href="#Как-менялись-продажи-по-платформам" data-toc-modified-id="Как-менялись-продажи-по-платформам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Как менялись продажи по платформам</a></span></li><li><span><a href="#Определяем-актуальный-период-для-анализа" data-toc-modified-id="Определяем-актуальный-период-для-анализа-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Определяем актуальный период для анализа</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам?" data-toc-modified-id="Какие-платформы-лидируют-по-продажам?-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Какие платформы лидируют по продажам?</a></span></li><li><span><a href="#Построим-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам" data-toc-modified-id="Построим-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Построим «ящик с усами» по глобальным продажам игр в разбивке по платформам</a></span></li><li><span><a href="#Посмотрим-как-отзывы-влияют-на-продажи-внутри-одной-популярной-платформы" data-toc-modified-id="Посмотрим-как-отзывы-влияют-на-продажи-внутри-одной-популярной-платформы-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Посмотрим как отзывы влияют на продажи внутри одной популярной платформы</a></span></li><li><span><a href="#Соотнесем-выводы-с-продажами-игр-на-других-платформах" data-toc-modified-id="Соотнесем-выводы-с-продажами-игр-на-других-платформах-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Соотнесем выводы с продажами игр на других платформах</a></span></li><li><span><a href="#Посмотрим-на-общее-распределение-игр-по-жанрам" data-toc-modified-id="Посмотрим-на-общее-распределение-игр-по-жанрам-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Посмотрим на общее распределение игр по жанрам</a></span></li><li><span><a href="#Общий-вывод-по-исследовательскому-анализу-данных" data-toc-modified-id="Общий-вывод-по-исследовательскому-анализу-данных-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Общий вывод по исследовательскому анализу данных</a></span></li></ul></li><li><span><a href="#Составить-портрет-пользователя-каждого-региона" data-toc-modified-id="Составить-портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Составить портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Портрет-пользователя-из-NA" data-toc-modified-id="Портрет-пользователя-из-NA-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Портрет пользователя из NA</a></span></li><li><span><a href="#Портрет-пользователя-из-EU" data-toc-modified-id="Портрет-пользователя-из-EU-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Портрет пользователя из EU</a></span></li><li><span><a href="#Портрет-пользователя-из-JP" data-toc-modified-id="Портрет-пользователя-из-JP-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Портрет пользователя из JP</a></span></li><li><span><a href="#Рассмотрим-игры-без-рейтинга---unknown.-Как-они-оказывают-влияние-на-портрет-пользователей-определенного-региона" data-toc-modified-id="Рассмотрим-игры-без-рейтинга---unknown.-Как-они-оказывают-влияние-на-портрет-пользователей-определенного-региона-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Рассмотрим игры без рейтинга - <code>unknown</code>. Как они оказывают влияние на портрет пользователей определенного региона</a></span></li><li><span><a href="#Вывод-по-портретам-пользователей" data-toc-modified-id="Вывод-по-портретам-пользователей-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вывод по портретам пользователей</a></span></li></ul></li><li><span><a href="#Проверить-гипотезы" data-toc-modified-id="Проверить-гипотезы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверить гипотезы</a></span><ul class="toc-item"><li><span><a href="#Распределение-среднего-количества-пользовательских-оценок-по-платформам-XOne-и-PC" data-toc-modified-id="Распределение-среднего-количества-пользовательских-оценок-по-платформам-XOne-и-PC-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Распределение среднего количества пользовательских оценок по платформам XOne и PC</a></span></li><li><span><a href="#Распределение-среднего-количества-пользовательских-оценок-по-жанрам-Action-и-Sports" data-toc-modified-id="Распределение-среднего-количества-пользовательских-оценок-по-жанрам-Action-и-Sports-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Распределение среднего количества пользовательских оценок по жанрам Action и Sports</a></span></li><li><span><a href="#Проверяем-гипотезу:-средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые" data-toc-modified-id="Проверяем-гипотезу:-средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Проверяем гипотезу: средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a></span></li><li><span><a href="#Проверяем-гипотезу:-средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные" data-toc-modified-id="Проверяем-гипотезу:-средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Проверяем гипотезу: средние пользовательские рейтинги жанров Action и Sports разные</a></span></li><li><span><a href="#Вывод-по-исследованию-гипотез" data-toc-modified-id="Вывод-по-исследованию-гипотез-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Вывод по исследованию гипотез</a></span></li></ul></li><li><span><a href="#Общие-выводы-по-исследованию" data-toc-modified-id="Общие-выводы-по-исследованию-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общие выводы по исследованию</a></span></li></ul></div>

# %% [markdown]
# # Описание
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
# ____________________
#
# **Цель исследования**
#
# Выявить определяющие успешность игры закономерности на основе данных за 2016 год. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании в 2017 году
# ____________________
#
# **Ход исследования**
#
# 1. Открыть файл с данными и изучить общую информацию (путь к файлу: /datasets/games.csv)
#
#
# 2. Предобработка данных:
# -  заменить названия столбцов (привести к нижнему регистру)
# -  преобразовать данные в нужные типы. Описать, в каких столбцах заменили тип данных и почему
# -  обработать пропуски - при необходимости
# -  объяснить, почему заполнили пропуски определённым образом или почему не стали это делать
# -  описать причины, которые могли привести к пропускам
# -  обратить внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разобрать это значение и описать, как его обработать
# - посчитать суммарные продажи во всех регионах и записать их в отдельный столбец
#
# 3. Провести исследовательский анализ данных:
# - посмотреть сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - посмотреть как менялись продажи по платформам. Выбрать платформы с наибольшими суммарными продажами и построить распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - взять данные за соответствующий актуальный период. Актуальный период определить самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год
# - не учитывать в работе данные за предыдущие годы
# - какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ
# - построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Описать результат
# - посмотреть как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построить диаграмму рассеяния и посчитать корреляцию между отзывами и продажами. Сформулировать выводы
# - соотнести выводы с продажами игр на других платформах
# - посмотреть на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# 4. Составить портрет пользователя каждого региона (определить для пользователя каждого региона - NA, EU, JP)
# - самые популярные платформы (топ-5). Описать различия в долях продаж
# - самые популярные жанры (топ-5). Пояснить разницу
# - влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# 5. Проверить гипотезы
# - средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# - средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные
# - задать самостоятельно пороговое значение alpha
# - пояснить как сформулировали нулевую и альтернативную гипотезы
# - пояснить какой критерий применили для проверки гипотез и почему
#
# 6. Написать общий вывод
#
# ____________________
# **Описание данных**
# - `name` — название игры
# - `platform` — платформа
# - `year_of_release` — год выпуска
# - `genre` — жанр игры
# - `na_sales` — продажи в Северной Америке (миллионы проданных копий)
# - `eu_sales` — продажи в Европе (миллионы проданных копий)
# - `jp_sales` — продажи в Японии (миллионы проданных копий)
# - `other_sales` — продажи в других странах (миллионы проданных копий)
# - `critic_score` — оценка критиков (максимум 100)
# - `user_score` — оценка пользователей (максимум 10)
# - `rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию
# - `general_sales` - общая сумма продаж
#
# Данные за 2016 год могут быть неполными
#
# **Переменные**
# - **data** = исходный датафрейм
# - **platform_sales** = общая сумма продаж по всем платформам
# - **data_selection** = выборка данных только за 2015-16 гг
# - **top_5_platform** = топ-платформы за 2015-16 гг
# - **data_selection_2015** = выборка данных только за 2015 г
# ____________________
# **И примерно так выглядел автор этого исследования, проводя в нем многие часы 🙃**
# ![IVEGGW3KHJDNZA4XX2NARBXVCY.jfif](attachment:IVEGGW3KHJDNZA4XX2NARBXVCY.jfif)

# %% [markdown]
# ## Открываем файл с данными и изучаем общую информацию

# %% [markdown]
# ### Загрузим данные из файла в датафрейм. Выведем первые 5 строк на экран

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats as st
import numpy as np
import pandas as pd

data = pd.read_csv('/datasets/games.csv')
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# ### Выведем основную информацию о датафрейме с помощью метода info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Смотрим числовое описание данных

# %%
data.describe(include = 'all')
# Out:
#                                Name Platform  Year_of_Release   Genre  \
# count                         16713    16715     16446.000000   16713
# unique                        11559       31              NaN      12
# top     Need for Speed: Most Wanted      PS2              NaN  Action
# freq                             12     2161              NaN    3369
# mean                            NaN      NaN      2006.484616     NaN
# std                             NaN      NaN         5.877050     NaN
# min                             NaN      NaN      1980.000000     NaN
# 25%                             NaN      NaN      2003.000000     NaN
# 50%                             NaN      NaN      2007.000000     NaN
# 75%                             NaN      NaN      2010.000000     NaN
# max                             NaN      NaN      2016.000000     NaN
#
#             NA_sales      EU_sales      JP_sales   Other_sales  Critic_Score  \
# ...

# %% [markdown]
# ### Чтобы увидеть плотность распределения и выбросы, построим общую гистограмму для всех числовых столбцов таблицы

# %%
data.hist(figsize=(10, 10));

# %% [markdown]
# ### Общий вывод после изучения данных

# %% [markdown]
# - были импортированы необходимые для работы библиотеки
# - данные загрузили в датафрейм
# - просмотрели числовое и графическое описание данных
#
# 👀 Видим недостатки:
# - пропуски
# - некорректный регистр названий столбцов
# - значения с плавающей точкой вместо целочисленных
# - некорректные типы данных
#
# Их исправим далее

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Найдем и изучим пропущенные значения в столбцах

# %%
data.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %%
#проверим колличество пропусков в %
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_e0b71_row0_col0,#T_e0b71_row1_col0,#T_e0b71_row3_col0,#T_e0b71_row4_col0,#T_e0b71_row5_col0,#T_e0b71_row6_col0,#T_e0b71_row7_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_e0b71_row2_col0{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_e0b71_row8_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e0b71_row9_col0,#T_e0b71_row10_col0{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }</style><table id="T_e0b71_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e0b71_level0_row0" class="row_heading level0 row0" >Name</th>
#                         <td id="T_e0b71_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# 👀 **Вероятные причины пропусков:**
# - отсутствие информации по объекту + неполные данные за 2016 год
# - ESRB предоставляет рейтинги видеоигр для США, Канады и Мексики. До ESRB (1994 год) рейтинги видеоигр были на уровне производителей консолей (например у Nintendo и Sega была своя собственная рейтинговая система, которую тут не учли). К тому же, в других странах есть собственные рейтинги - PEGI и CERO
#
# **Что делаем с пропусками:**
# - `Name`, `Year_of_Release`, `Genre` - можно удалить (до 2% от общего объема данных)
# - `Critic_Score`, `User_Score` - оставляем пропуски, тк нет возможности заполнить достоверными значениями
# - `Rating` - поставим заглушку "unknown", тк не известно имеют ли эти игры рейтинг вообще

# %%
# удаляем пропуски в Name, Year_of_Release, Genre
data = data.dropna(subset=['Name'])  
data = data.dropna(subset=['Year_of_Release']) 
data = data.dropna(subset=['Genre']) 

# проверяем удаление
data.isna().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8461
# User_Score         6605
# Rating             6676
# dtype: int64

# %% [markdown]
# ### Заменим названия столбцов

# %%
# приведем к нижнему регистру
data.columns = data.columns.str.lower()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  float64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       9839 non-null   object
#  10  rating           9768 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Приведем значения к нужному типу данных

# %% [markdown]
# ####  `year_of_release` (float 👉 int)

# %%
data['year_of_release'] = data['year_of_release'].astype('int') 
data['year_of_release']
# Out:
# 0        2006
# 1        1985
# 2        2008
# 3        2009
# 4        1996
#          ...
# 16710    2016
# 16711    2006
# 16712    2016
# 16713    2003
# 16714    2016
# Name: year_of_release, Length: 16444, dtype: int64

# %% [markdown]
# Теперь год будет красиво отображаться на графиках

# %% [markdown]
# ### Изучим уникальные значения в столбцах и устраним дубликаты

# %% [markdown]
# #### `name`

# %%
print(data['name'].value_counts().loc[lambda x : x > 1])
print('✍Количество явных дубликатов:', data['name'].duplicated().sum())
# Out:
# Need for Speed: Most Wanted       12
# Ratatouille                        9
# LEGO Marvel Super Heroes           9
# FIFA 14                            9
# Madden NFL 07                      8
#                                   ..
# NBA Street                         2
# Vigilante 8: 2nd Offense           2
# The Darkness                       2
# Hummer Badlands                    2
# Test Drive: Eve of Destruction     2
# Name: name, Length: 2748, dtype: int64
# ✍Количество явных дубликатов: 5018

# %% [markdown]
# 👀 Видим, что почти треть названий игр встречаются по несколько раз. Это нормально, с учетом, что одни и те же игры могли выходить на разных платформах в разное время

# %% [markdown]
# #### `platform`

# %%
print('Проверим неявные дубликаты:', data['platform'].unique())
# Out:
# Проверим неявные дубликаты: ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']

# %% [markdown]
# 👀 Дублей нет, оставляем

# %% [markdown]
# #### `genre`

# %%
data['genre'].value_counts()
# Out:
# Action          3307
# Sports          2306
# Misc            1721
# Role-Playing    1481
# Shooter         1296
# Adventure       1293
# Racing          1226
# Platform         878
# Simulation       857
# Fighting         837
# Strategy         673
# Puzzle           569
# Name: genre, dtype: int64

# %% [markdown]
# 👀 Неявных дублей нет, оставляем

# %% [markdown]
# #### `user_score`

# %%
data['user_score'].value_counts()
# Out:
# tbd    2376
# 7.8     322
# 8       285
# 8.2     276
# 8.3     252
#        ...
# 0.9       2
# 0.5       2
# 1.1       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# 👀 Видим значение tbd (англ. "to be determined" - пока не определён) - лучше всего заменить на NaN (по сути, одно и то же, однако далее NaN не будет выдавать ошибку в расчетах, тк Python умеет их игнорировать)

# %%
# Заменим пропуски в user_score ('tbd' 👉 NaN)
data.loc[data['user_score'] == 'tbd', 'user_score'] = float('nan')
data['user_score'].value_counts()
# Out:
# 7.8    322
# 8      285
# 8.2    276
# 8.3    252
# 7.5    249
#       ...
# 0.9      2
# 0.5      2
# 1.5      2
# 9.7      1
# 0        1
# Name: user_score, Length: 95, dtype: int64

# %%
# Заменим тип данных (object 👉 float)
data['user_score'] = data['user_score'].astype('float')

# %% [markdown]
# #### `rating`

# %%
data['rating'].value_counts()
# Out:
# E       3921
# T       2905
# M       1536
# E10+    1393
# EC         8
# K-A        3
# AO         1
# RP         1
# Name: rating, dtype: int64

# %% [markdown]
# 👀 Приведем расшифровку рейтинга, для лучшего понимания:
# - E («Everyone») — для всех возрастов
# - T («Teen») — подросткам от 13 лет
# - M («Mature») — для взрослых от 17 лет
# - E10+ («Everyone 10 and older») — для всех от 10 лет и старше
# - EC («Early childhood») — для детей младшего возраста от 3 лет
# - K-A («for Kids to Adults») - для всех возрастов (рейтинг использовался до 1998 года, когда он был переименован в E)
# - RP («Rating Pending») — продукт был отправлен в ESRB и ожидает присвоения рейтинга
# - AO («Adults Only 18+») — только для взрослых старше 18 лет

# %%
# Заменить пропуски в `rating` на заглушку (NaN 👉 'unknown')
def rating_replace(wrong_rating, correct_rating):
    data['rating'] = data['rating'].replace(wrong_rating, correct_rating)
rating_replace(np.NaN, 'unknown')

# Проверим заполнение
data['rating'].value_counts()
# Out:
# unknown    6676
# E          3921
# T          2905
# M          1536
# E10+       1393
# EC            8
# K-A           3
# AO            1
# RP            1
# Name: rating, dtype: int64

# %% [markdown]
# ### Cбросим индексацию после удаления строк и еще раз взглянем на данные

# %%
data.reset_index(drop=True,inplace=True)
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16444 entries, 0 to 16443
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int64
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           16444 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB
# None

# %%
data.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16444.000000  16444.000000  16444.000000  16444.000000
# mean       2006.486256      0.264012      0.145930      0.078487
# std           5.875525      0.818378      0.506716      0.311100
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score   user_score
# count  16444.000000   7983.000000  7463.000000
# mean       0.047594     68.994363     7.126330
# std        0.188005     13.920060     1.499447
# min        0.000000     13.000000     0.000000
# 25%        0.000000     60.000000     6.400000
# 50%        0.010000     71.000000     7.500000
# 75%        0.030000     79.000000     8.200000
# ...

# %% [markdown]
# ### Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец `general_sales`

# %%
data['general_sales'] = data['na_sales'] + data['eu_sales'] + data['other_sales'] + data['jp_sales']
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16439  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16440               LMA Manager 2007     X360             2006        Sports
# 16441        Haitaka no Psychedelica      PSV             2016     Adventure
# 16442               Spirits & Spells      GBA             2003      Platform
# 16443            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# ### Общий вывод после предобработки данных

# %% [markdown]
# В ходе работы мы:
# - нашли и изучили пропущенные значения в столбцах
# - сформулировали возможные причины пропусков, решили чем их будем заполнять
# - привели названия столбцов к нижнему регистру
# - привели значения к нужному типу данных
# - проверили на явные/неявные дубликаты, определили что делать с уникальными значениями
# - сбросили индексацию после проведенных манипуляций
# - выделили суммарные продажи во всех регионах в отдельный столбец `general_sales`

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Сколько игр выпускалось в разные годы

# %%
# Выведем данные на гистограмме
data['year_of_release'].hist(bins=37, figsize=(10, 8));
plt.title('Сколько игр выпускалось в разные годы')
plt.xlabel('Год')
plt.ylabel('Количество игр')
plt.show()

# Построим "ящик с усами"
data.boxplot(['year_of_release']);
plt.ylim(1980,2020)
plt.title('Сколько игр выпускалось в разные годы')
plt.xlabel('Год')
plt.ylabel('Количество игр')
plt.show()

# %%
print('Количество игр до 1993 г: ' + str(data.query('year_of_release < 1993')['year_of_release'].count()) )
print('Количество игр до 2000 г: ' + str(data.query('year_of_release < 2000')['year_of_release'].count()) )
print('Остальные: ' + str(data.query('year_of_release >= 2000')['year_of_release'].count()) )
# Out:
# Количество игр до 1993 г: 305
# Количество игр до 2000 г: 1974
# Остальные: 14470

# %% [markdown]
# 👀 Видим, что до 93 г выходило менее 100 игр в год (в то время компьютерные технологии были развиты не так сильно). С 90-х до 2000х начало набирать обороты. С 2002 г - резкий скачок.
#
# Чтобы не учитывать отжившие тренды в такой быстроменяющейся индустрии как видеоигры, можно отбросить данные до 2000 г, чтобы иметь более репрезентативную общую выборку для дальнейшего анализа.

# %%
#удаляем ненужные строки и еще раз смотрим на график
data.drop(index=data.query('year_of_release < 2000').index,inplace=True)

data['year_of_release'].hist(bins=17, figsize=(10, 8));
plt.title('Сколько игр выпускалось в разные годы')
plt.xlabel('Год')
plt.ylabel('Количество игр')
plt.show()

# %% [markdown]
# 👀 Пик количества выходов игр - 2008-09 гг (около 1400). Заметно снижение с 2012 года

# %% [markdown]
# ### Как менялись продажи по платформам

# %%
# На какую платформу выпускали больше всего игр
data.pivot_table(index='platform', values='name', aggfunc='count') \
    .sort_values(by = 'name', ascending = False) \
    .head(8)
# Out:
#           name
# platform
# PS2       2127
# DS        2120
# PS3       1306
# Wii       1286
# X360      1232
# PSP       1193
# PC         917
# GBA        811

# %%
# Выведем общую сумму продаж по платформам в переменную
platform_sales = data.groupby('platform').agg({'general_sales':'sum'}) \
    .sort_values(by = 'general_sales', ascending = False)

# Построим график
plt.figure(figsize=(15,5))
sns.barplot(x=platform_sales.index,y=platform_sales['general_sales'])
plt.title('Продажи по платформам за весь период')
plt.xlabel('Название платформы')
plt.ylabel('Количество продаж')
# Out:
# Text(0, 0.5, 'Количество продаж')

# %% [markdown]
# 👀 На графике видно, что самые популярные игровые платформы за весь период это PS2, X360, PS3, Wii, DS, PS4. Среди них есть уже устаревшие к 2016 г платформы, поэтому проверим распределение по годам

# %%
data.pivot_table(index='year_of_release', columns = 'platform', values='general_sales', aggfunc='sum').plot(grid=True, figsize=(19, 8))
plt.title('Продажи по платформам в разные годы')
plt.xlabel('Год')
plt.ylabel('Суммарное кол-во проданных копий игр (млн)')
plt.show()

# %% [markdown]
# 👀 Видим, что:
# - практически каждый год появлялись новые платформы
# - примерный срок их жизни 7-10 лет
# - пик продаж наступает примерно через 5 лет после выпуска консоли
# - топы платформ по общему кол-ву продаж игр постепенно начали заменяться другими, более современными версиями (но их показатели скромнее их предшественников)
#
# Нет смысла включать в выборку неактуальные платформы, чьи продажи в последние несколько лет стремятся к 0 или уже "отжили" свой цикл, поэтому далее выберем 5 актуальных

# %% [markdown]
# ### Определяем актуальный период для анализа

# %% [markdown]
# ✂ Мы хотим анализировать данные для прогноза на 2017 год. Для этого, лучше всего взять выборку за последние 2 года (2015-16 гг)

# %%
# Оставляем данные за соответствующий актуальный период
data_selection = data.query('2015 <= year_of_release <= 2016')
data_selection
# Out:
#                                 name platform  year_of_release       genre  \
# 31         Call of Duty: Black Ops 3      PS4             2015     Shooter
# 77                           FIFA 16      PS4             2015      Sports
# 87      Star Wars Battlefront (2015)      PS4             2015     Shooter
# 94                           FIFA 17      PS4             2016      Sports
# 99         Call of Duty: Black Ops 3     XOne             2015     Shooter
# ...                              ...      ...              ...         ...
# 16428          The Longest 5 Minutes      PSV             2016      Action
# 16432               Strawberry Nauts      PSV             2016   Adventure
# 16439  Samurai Warriors: Sanada Maru      PS3             2016      Action
# 16441        Haitaka no Psychedelica      PSV             2016   Adventure
# 16443            Winning Post 8 2016      PSV             2016  Simulation
#
# ...

# %% [markdown]
# ### Какие платформы лидируют по продажам?

# %%
data_selection.pivot_table(index='year_of_release', columns = 'platform', values='general_sales', aggfunc='sum').plot(grid=True, figsize=(19, 8))
plt.title('Продажи по платформам в разные годы')
plt.xlabel('Год')
plt.ylabel('Суммарное кол-во проданных копий игр (млн)')
plt.show()

# %% [markdown]
# 👀 Наблюдается общее падение, но это все еще подходит для рассмотрения (помним, что данные за 2016 год неполные)

# %%
# Выведем топ-5 платформ по суммарному кол-ву продаж за 2015-16 гг
data_selection.pivot_table(index='platform', values='general_sales', aggfunc='sum') \
    .sort_values(by='general_sales', ascending=False) \
    .head()
# Out:
#           general_sales
# platform
# PS4              188.15
# XOne              86.29
# 3DS               42.92
# WiiU              20.95
# PS3               20.42

# %% [markdown]
# ### Построим «ящик с усами» по глобальным продажам игр в разбивке по платформам

# %%
# Сохраним топ-платформы за 2015-16 гг в переменной
top_5_platform = data_selection.query("platform == ['PS4', 'XOne', '3DS', 'WiiU', 'PS3']")

# %%
# Посмотрим на распределение данных с помощью boxplot() по продажам игр в разбивке по топ-платформам за 2015-16 гг
top_5_platform.boxplot(column='general_sales', by='platform', figsize=(20,9))
plt.title('Продажи игр по топ-платформам (2015-16 гг)')
plt.xlabel('Платформы')
plt.ylabel('Суммарное кол-во проданных копий игр (млн)')
plt.ylim(0, 1.0)
plt.show()

# %% [markdown]
# 👀 На графике видим выбивающиеся значения. Их оставим, тк это могут быть скачки продаж популярных игр

# %%
# Посмотрим на распределение значений по топ-платформам
top_5_platform.groupby('platform')['general_sales'].describe()
# Out:
#           count      mean       std   min    25%    50%     75%    max
# platform
# 3DS       132.0  0.325152  0.798620  0.01  0.030  0.090  0.2325   7.14
# PS3       111.0  0.183964  0.342696  0.01  0.020  0.060  0.1600   2.70
# PS4       301.0  0.625083  1.457063  0.01  0.050  0.120  0.4200  14.63
# WiiU       42.0  0.498810  0.850240  0.01  0.050  0.215  0.5175   4.44
# XOne      167.0  0.516707  0.965940  0.01  0.035  0.130  0.5550   7.39

# %%
top_5_platform['general_sales'].describe()
# Out:
# count    753.000000
# mean       0.476401
# std        1.116464
# min        0.010000
# 25%        0.040000
# 50%        0.110000
# 75%        0.390000
# max       14.630000
# Name: general_sales, dtype: float64

# %% [markdown]
# 👀
# - медианные значения у всех платформ - разные
# - медианные продажи, по нисходящей - WiiU, затем XOne, после PS4, 3DS, PS3 на последнем месте
#
# Успех WiiU связан с наличием в данной модели нового контроллера, который мог использоваться как дополнительный сенсорный экран. Также браузер WiiU на момент ее выхода (конец 2012 года) был одним из лучших среди домашних консолей.
#
# Положение XOne и PS4 можно объяснить тем, что данные приставки позднее остальных вышли на рынки. Часть стран увидела их в конце 2013, часть только во второй половине 2014.
#
# Nintendo 3DS удерживала позиции благодаря развитию серии линейки.
#
# PS3 на данном промежутке времени отошли на второй план, уступив место своей более новой версии - PS4

# %% [markdown]
# ### Посмотрим как отзывы влияют на продажи внутри одной популярной платформы

# %%
# Вытащим данные по PS4 за 2015-16 гг в отдельную переменную
data_ps4 = top_5_platform[top_5_platform['platform']=='PS4']

# %%
# Построим диаграмму рассеивания для PS4, отобразив отзывы пользователей
data_ps4.plot(x='user_score', y='general_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.title('Зависимость продаж от отзывов пользователей для PS4')
plt.show()

# Вычислим коэффициент корреляции
ps4_user_cor = data_ps4['user_score'].corr(data_ps4['general_sales'])
print('Коэффициент корреляции: ', ps4_user_cor)
# Out:
# Коэффициент корреляции:  -0.05973845712638215

# %% [markdown]
# 👀 Слабая отрицательная корреляция = нет взаимосвязи. Есть примеры со средними отзывами, но высокими продажами

# %%
# Построим диаграмму рассеивания для PS4, отобразив отзывы критиков
data_ps4.plot(x='critic_score', y='general_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.title('Зависимость продаж от отзывов критиков для PS4')
plt.show()

# Вычислим коэффициент корреляции
ps4_critic_cor = data_ps4['critic_score'].corr(data_ps4['general_sales'])
print('Коэффициент корреляции: ', ps4_critic_cor)
# Out:
# Коэффициент корреляции:  0.3928485555130601

# %% [markdown]
# 👀 Умеренная положительная корреляция = как правило, с увеличением среднего рейтинга критиков увеличивается и средний уровень выручки

# %% [markdown]
# 👀 Для обоих корреляций:
# - большую часть составляют высокие оценки
# - критики точнее прогнозируют успех игры, в отличии от пользователей (что сильнее влияет на кол-во продаж игр на консоль)
# - в оценках пользователей есть игры со средней оценкой, но большим количеством продаж, чего почти не встретишь в оценках критиков

# %% [markdown]
# ### Соотнесем выводы с продажами игр на других платформах

# %%
# Посмотрим на распределение данных с помощью boxplot() по продажам игр по всем платформам за 2015-16 гг
data_selection.boxplot(column='general_sales', by='platform', figsize=(20,9))
plt.ylim(0, 2.0)
plt.show()

# %%
data_selection.groupby('platform')['general_sales'].describe()
# Out:
#           count      mean       std   min    25%    50%     75%    max
# platform
# 3DS       132.0  0.325152  0.798620  0.01  0.030  0.090  0.2325   7.14
# PC        104.0  0.132404  0.209449  0.01  0.020  0.050  0.1425   1.28
# PS3       111.0  0.183964  0.342696  0.01  0.020  0.060  0.1600   2.70
# PS4       301.0  0.625083  1.457063  0.01  0.050  0.120  0.4200  14.63
# PSP         3.0  0.040000  0.034641  0.02  0.020  0.020  0.0500   0.08
# PSV       195.0  0.053846  0.063669  0.01  0.020  0.030  0.0600   0.41
# Wii         5.0  0.264000  0.390487  0.01  0.030  0.150  0.1800   0.95
# WiiU       42.0  0.498810  0.850240  0.01  0.050  0.215  0.5175   4.44
# X360       48.0  0.280833  0.381207  0.01  0.040  0.110  0.3525   1.70
# XOne      167.0  0.516707  0.965940  0.01  0.035  0.130  0.5550   7.39

# %% [markdown]
# 👀 По медиане получился следующий рейтинг:
# - WiiU *
# - Wii - долго оставалась одной из самых продаваемых консолей во всем мире. Изначально, для охвата наибольшей аудитории, на консоль была поставлена цена в 200 долларов, в отличии от X360 и PS3 за 300 и 500 соответственно. Она поддерживала множество старых казуальных игр, но её популярность на фоне других стала угасать. Несмотря на прекращение работы Wii, некоторые разработчики продолжали выпускать игры для Wii и после 2013 года
# - XOne *
# - PS4 *
# - X360 - предыдущая версия XOne, на которую продолжали выпускать игры, поддерживающие в тч и новую консоль
# - 3DS *
# - PS3 *
# - PC - положение ПК объясняется выпуском эксклюзивов, которых были только на консолях. К тому же, купить приставку было дешевле
# - PSV - с технической точки зрения портативная консоль была прорывной. Но было множество технических и маркетинговых факторов, не позволивших ей стрельнуть + на неё не поставили достаточно игр, которые могли бы удовлетворить пользователей
# - PSP - предшественник PSV, который постепенно стал уходить с рынка

# %%
# Вытащим данные по остальным топ-5 платформам (2015-16 гг) в переменные 
# PS3 не будем смотреть, тк PS4 - новее её
data_xone = data_selection[data_selection['platform']=='XOne']
data_3ds = data_selection[data_selection['platform']=='3DS']
data_wiiu = data_selection[data_selection['platform']=='WiiU']

# %%
# 1 Построим диаграммы рассеивания по отзывам пользователей (2015-16 гг) для XOne
data_xone.plot(x='user_score', y='general_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.title('Зависимость продаж от отзывов пользователей (XOne)')
plt.show()
# Рассчитаем коэффициент корреляции для XOne
xone_user_cor = data_xone['user_score'].corr(data_xone['general_sales'])
print('Коэффициент корреляции (XOne): ', xone_user_cor)


# 2 Построим диаграммы рассеивания по отзывам пользователей (2015-16 гг) для 3DS
data_3ds.plot(x='user_score', y='general_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.title('Зависимость продаж от отзывов пользователей (3DS)')
plt.show()
# Рассчитаем коэффициент корреляции для 3DS
user_cor_3ds = data_3ds['user_score'].corr(data_3ds['general_sales'])
print('Коэффициент корреляции (3DS): ', user_cor_3ds)


# 3 Построим диаграммы рассеивания по отзывам пользователей (2015-16 гг) для WiiU
data_wiiu.plot(x='user_score', y='general_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.title('Зависимость продаж от отзывов пользователей (WiiU)')
plt.show()
# Рассчитаем коэффициент корреляции для WiiU
wiiu_user_cor = data_wiiu['user_score'].corr(data_wiiu['general_sales'])
print('Коэффициент корреляции (WiiU): ', wiiu_user_cor)
# Out:
# Коэффициент корреляции (XOne):  -0.04146733387366271
# Коэффициент корреляции (3DS):  0.19879627008102982
# Коэффициент корреляции (WiiU):  0.3635185724809445

# %%
# 1 Построим диаграммы рассеивания по отзывам критиков (2015-16 гг) для XOne
data_xone.plot(x='critic_score', y='general_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.title('Зависимость продаж от отзывов критиков (XOne)')
plt.show()
# Рассчитаем коэффициент корреляции для XOne
xone_critic_cor = data_xone['critic_score'].corr(data_xone['general_sales'])
print('Коэффициент корреляции (XOne): ', xone_critic_cor)


# 2 Построим диаграммы рассеивания по отзывам критиков (2015-16 гг) для 3DS
data_3ds.plot(x='critic_score', y='general_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.title('Зависимость продаж от отзывов критиков (3DS)')
plt.show()
# Рассчитаем коэффициент корреляции для 3DS
critic_cor_3ds = data_3ds['critic_score'].corr(data_3ds['general_sales'])
print('Коэффициент корреляции (3DS): ', critic_cor_3ds)


# 3 Построим диаграммы рассеивания по отзывам критиков (2015-16 гг) для WiiU
data_wiiu.plot(x='critic_score', y='general_sales', kind='scatter', alpha=0.3, figsize=(8,8), grid=True)
plt.title('Зависимость продаж от отзывов критиков (WiiU)')
plt.show()
# Рассчитаем коэффициент корреляции для WiiU
wiiu_critic_cor = data_wiiu['critic_score'].corr(data_wiiu['general_sales'])
print('Коэффициент корреляции (WiiU): ', wiiu_critic_cor)
# Out:
# Коэффициент корреляции (XOne):  0.43088874582136805
# Коэффициент корреляции (3DS):  0.17757455046092874
# Коэффициент корреляции (WiiU):  0.3170457117696218

# %% [markdown]
# 👀 Итого по корреляции PS4 (-0.059 юзеры / 0.392 критики) с другими, чуть менее продаваемыми по играм, платформами:
# - XOne (-0.041 юзеры / 0.430 критики) - показывают схожие результаты, покупатели так же прислушиваются больше к критикам, нежели к оценкам других пользователей
# - 3DS (0.198 юзеры / 0.177 критики) - в целом слабая корреляция (даже по отношению к PS4). Однако мнение пользователей здесь оказалось весомее критиков (это логично, тк консоль далеко не новая)
# - WiiU (0.363 юзеры / 0.317 критики) - отзывы пользователей и критиков практически одинаково умеренно влияют на продажи игр

# %% [markdown]
# ### Посмотрим на общее распределение игр по жанрам

# %%
data.boxplot(column='general_sales', by='genre', figsize=(20,9))
plt.ylim(0, 1.0)
plt.show()

# %%
data.pivot_table(index='genre', values='general_sales', aggfunc='median') \
    .plot(kind='pie', subplots=True, figsize=(80, 10));

# %%
# Выделим ТОП-5 жанров по медианному значению прибыльности
data.groupby('genre').agg({'general_sales':'median'}) \
    .sort_values(by = 'general_sales', ascending = False) \
    .head()
# Out:
#           general_sales
# genre
# Shooter            0.24
# Platform           0.21
# Sports             0.21
# Fighting           0.19
# Action             0.18

# %%
data.groupby('genre').agg({'general_sales':'median'}) \
    .sort_values(by = 'general_sales', ascending = True) \
    .head()
# Out:
#             general_sales
# genre
# Adventure            0.05
# Strategy             0.08
# Puzzle               0.09
# Simulation           0.14
# Misc                 0.15

# %% [markdown]
# 👀 На последних местах располагаются жанры Adventure, Strategy и Puzzle, хотя их производство сильно дешевле, чем Shooter.

# %% [markdown]
# Проверим, разнятся ли данные с нашей выборкой топ-5

# %%
top_5_platform.pivot_table(index='genre', values='general_sales', aggfunc='median') \
    .plot(kind='pie', subplots=True, figsize=(80, 10));

# %%
top_5_platform.groupby('genre').agg({'general_sales':'median'}) \
    .sort_values(by = 'general_sales', ascending = False) \
    .head()
# Out:
#               general_sales
# genre
# Shooter               0.570
# Role-Playing          0.185
# Sports                0.170
# Simulation            0.140
# Platform              0.140

# %%
top_5_platform.groupby('genre').agg({'general_sales':'median'}) \
    .sort_values(by = 'general_sales', ascending = True) \
    .head()
# Out:
#            general_sales
# genre
# Puzzle             0.045
# Adventure          0.050
# Misc               0.060
# Strategy           0.070
# Action             0.080

# %% [markdown]
# 👀 Shooter, Platform, Sports - сохранили лидерские позиции. Fighting и Action - уступили. Simulation и Role-Playing набрал популярность.
#
# Shooter остался самым массовым жанром.
#
# Среди самых низких по продажам картина не сильно изменилась. Action	переместился в конец списка

# %% [markdown]
# ### Общий вывод по исследовательскому анализу данных

# %% [markdown]
# - В 90-е игровая индустрия только развивалась. И только к 2008 г начало набирать стремительные обороты. Пик продаж в 2008-9 гг. С 2012 резкий спад
#
# - Самые популярные платформы за все время - PS2, X360, PS3, Wii, DS, PS4
#
# - Среднее время жизни платформы - 7-10 лет
#
# - Больше всего игр выпустили на PS2, DS и PS3. В первой пятерке по продажам за два последних года - PS4, XOne, 3DS, WiiU и PS3
# - Критики точнее прогнозируют успех игры, в отличии от пользователей (что влияет на кол-во продаж игр на консоль). В более старых моделях консолей, оценки пользователей могут играть бОльшую роль
#
# - Самый популярный жанр игр - Shooter. Замыкают списки - Puzzle, Adventure

# %% [markdown]
# ## Составить портрет пользователя каждого региона

# %% [markdown]
# Определим для пользователя каждого региона - NA, EU, JP:
# - самые популярные платформы (топ-5). Опишем различия в долях продаж
# - самые популярные жанры (топ-5). Поясним разницу
# - влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# ### Портрет пользователя из NA

# %%
# самые популярные платформы (топ-5) в 2015-16 гг
na_platform = data_selection.groupby('platform')['na_sales'].sum().sort_values(ascending=False).head()
na_platform
# Out:
# platform
# PS4     63.86
# XOne    50.30
# 3DS     10.31
# WiiU     8.86
# X360     8.05
# Name: na_sales, dtype: float64

# %%
na_platform.plot(x='platform', y='na_sales', kind='bar');
plt.title('Самые популярные платформы в NA')
plt.xlabel('Платформа')
plt.ylabel('Продажи игр (млн.)')
plt.show()

# %%
# самые популярные жанры (топ-5) в 2015-16 гг
na_genre = data_selection.groupby('genre')['na_sales'].sum().sort_values(ascending=False).head()
na_genre
# Out:
# genre
# Shooter         48.18
# Action          33.68
# Sports          26.31
# Role-Playing    19.82
# Misc             5.58
# Name: na_sales, dtype: float64

# %%
na_genre.plot(x='genre', y='na_sales', kind='bar');
plt.title('Самые популярные жанры игр в NA')
plt.xlabel('Жанр')
plt.ylabel('Продажи игр (млн.)')
plt.show()

# %%
# влияет ли рейтинг ESRB на продажи в отдельном регионе?
na_esrb = data_selection.groupby('rating')['na_sales'].sum().sort_values(ascending=False).head()
na_esrb
# Out:
# rating
# M          47.03
# unknown    37.44
# E          26.59
# T          22.86
# E10+       17.87
# Name: na_sales, dtype: float64

# %%
na_esrb.plot(x='rating', y='na_sales', kind='bar');
plt.title('Самые популярные рейтинги игр в NA')
plt.xlabel('Рейтинг')
plt.ylabel('Продажи игр (млн.)')
plt.show()

# %% [markdown]
# 👀 Для NA:
# - Самые популярные платформы - PS4 и XOne.
# - Самые популярные жанры - Shooter, Action.
# - Самые популярные рейтинги - М и Е (Mature — для взрослых от 17 лет, Everyone — для всех возрастов)
# - Второй в рейтинге `unknown` - это игры без рейтинга (рассмотрим их отдельно в п. 4.4)

# %% [markdown]
# ### Портрет пользователя из EU

# %%
# самые популярные платформы (топ-5) в 2015-16 гг
eu_platform = data_selection.groupby('platform')['eu_sales'].sum().sort_values(ascending=False).head()
eu_platform
# Out:
# platform
# PS4     83.54
# XOne    28.10
# PC       9.10
# 3DS      7.39
# PS3      7.30
# Name: eu_sales, dtype: float64

# %%
eu_platform.plot(x='platform', y='eu_sales', kind='bar');
plt.title('Самые популярные платформы в EU')
plt.xlabel('Платформа')
plt.ylabel('Продажи игр (млн.)')
plt.show()

# %%
# самые популярные жанры (топ-5) в 2015-16 гг
eu_genre = data_selection.groupby('genre')['eu_sales'].sum().sort_values(ascending=False).head()
eu_genre
# Out:
# genre
# Shooter         40.28
# Action          34.82
# Sports          27.82
# Role-Playing    17.21
# Racing           6.52
# Name: eu_sales, dtype: float64

# %%
eu_genre.plot(x='genre', y='eu_sales', kind='bar');
plt.title('Самые популярные жанры игр в EU')
plt.xlabel('Жанр')
plt.ylabel('Продажи игр (млн.)')
plt.show()

# %%
# влияет ли рейтинг ESRB на продажи в отдельном регионе?
eu_esrb = data_selection.groupby('rating')['eu_sales'].sum().sort_values(ascending=False).head()
eu_esrb
# Out:
# rating
# M          45.54
# unknown    35.71
# E          34.83
# T          20.32
# E10+       11.54
# Name: eu_sales, dtype: float64

# %%
eu_esrb.plot(x='rating', y='eu_sales', kind='bar');
plt.title('Самые популярные рейтинги игр в EU')
plt.xlabel('Рейтинг')
plt.ylabel('Продажи игр (млн.)')
plt.show()

# %% [markdown]
# 👀 Для EU:
# - Самые популярные платформы - PS4 (с большим отрывом) и XOne.
# - Самые популярные жанры - Shooter и Action.
# - Самые популярные рейтинги - М и Е (Mature — для взрослых от 17 лет, Everyone — для всех возрастов)
# - Второй в рейтинге `unknown` - это игры без рейтинга (рассмотрим их отдельно в п. 4.4)

# %% [markdown]
# ### Портрет пользователя из JP

# %%
# самые популярные платформы (топ-5) в 2015-16 гг
jp_platform = data_selection.groupby('platform')['jp_sales'].sum().sort_values(ascending=False).head()
jp_platform
# Out:
# platform
# 3DS     23.55
# PS4     12.05
# PSV      8.41
# PS3      4.97
# WiiU     4.12
# Name: jp_sales, dtype: float64

# %%
jp_platform.plot(x='platform', y='jp_sales', kind='bar');
plt.title('Самые популярные платформы в JP')
plt.xlabel('Платформа')
plt.ylabel('Продажи игр (млн.)')
plt.show()

# %%
# самые популярные жанры (топ-5) в 2015-16 гг
jp_genre = data_selection.groupby('genre')['jp_sales'].sum().sort_values(ascending=False).head()
jp_genre
# Out:
# genre
# Action          23.05
# Role-Playing    13.41
# Shooter          3.79
# Misc             3.19
# Adventure        2.22
# Name: jp_sales, dtype: float64

# %%
jp_genre.plot(x='genre', y='jp_sales', kind='bar');
plt.title('Самые популярные жанры игр в JP')
plt.xlabel('Жанр')
plt.ylabel('Продажи игр (млн.)')
plt.show()

# %%
# влияет ли рейтинг ESRB на продажи в отдельном регионе?
jp_esrb = data_selection.groupby('rating')['jp_sales'].sum().sort_values(ascending=False).head()
jp_esrb
# Out:
# rating
# unknown    32.89
# T           7.70
# E           5.25
# M           4.29
# E10+        3.27
# Name: jp_sales, dtype: float64

# %%
jp_esrb.plot(x='rating', y='jp_sales', kind='bar');
plt.title('Самые популярные рейтинги игр в JP')
plt.xlabel('Рейтинг')
plt.ylabel('Продажи игр (млн.)')
plt.show()

# %% [markdown]
# 👀 Для JP:
# - Самые популярные платформы - 3DS и PS4.
# - Самые популярные жанры - Action и Role-Playing.
# - Самые популярные рейтинги - T и Е (Teen — подросткам от 13 лет, Everyone — для всех возрастов)
# - Первый в рейтинге `unknown` - это игры без рейтинга (рассмотрим их отдельно в п. 4.4)

# %% [markdown]
# ### Рассмотрим игры без рейтинга - `unknown`. Как они оказывают влияние на портрет пользователей определенного региона

# %%
# Количество `unknown` 
data_selection.groupby('rating').agg({'na_sales':'sum', 'eu_sales':'sum', 'jp_sales':'sum'})
# Out:
#          na_sales  eu_sales  jp_sales
# rating
# E           26.59     34.83      5.25
# E10+        17.87     11.54      3.27
# M           47.03     45.54      4.29
# T           22.86     20.32      7.70
# unknown     37.44     35.71     32.89

# %% [markdown]
# 👀 `unknown`:
# - второй в рейтинге для NA и EU
# - первый в JP
#
# Рейтинг ESRB в бОльшей степени влияет на европейских и американских игроков, чем на японских. В Японии, общая доля игр без оценок - больше

# %%
# Выборка с 'unknown' в рейтинге в 2015-16 гг
unknown_rating = data_selection[data_selection['rating']=='unknown']

# %%
# Какая есть закономерность среди разных платформ?
unknown_rating.pivot_table(index='platform', values='na_sales', aggfunc='sum') \
    .plot(kind='pie', subplots=True, figsize=(80, 8), autopct='%1.0f%%');

unknown_rating.pivot_table(index='platform', values='eu_sales', aggfunc='sum') \
    .plot(kind='pie', subplots=True, figsize=(80, 8), autopct='%1.0f%%');

unknown_rating.pivot_table(index='platform', values='jp_sales', aggfunc='sum') \
    .plot(kind='pie', subplots=True, figsize=(80, 8), autopct='%1.0f%%');

# %% [markdown]
# 👀 В топе платформ с неизвестным значением рейтинга:
# - **NA** - PS4 (45%), XOne (28%), 3DS (14%)
# - **EU** - PS4 (57%), XOne (16%), 3DS (11%)
# - **JP** - 3DS (55%), PSV (18%), PS4 (16%)
#
# Можно предположить, что `unknown` заменяет рейтинги, которые:
# - не применялись к локальным платформам разных стран, в которых были свои системы оценки - PEGI и CERO (тк не являлись обязательными)
# - игры, не выходившие за пределы экосистемы консоли
# - игры, для которых не назначался рейтинг ERSB вообще

# %% [markdown]
# ### Вывод по портретам пользователей

# %% [markdown]
# 👀 Пользователи из Америки и Европы отдают предпочтение PS4 и XOne. Причем XOne в Европе гораздо менее популярна, чем в Америке.
# Японцы отдают предпочтение Nintendo 3DS (PS4 почти вполовину менее популярна, а XOne вообще не вошел в топ-5).
#
# Не удивительно, почему у 3DS была своя аудитория - большое количество игр, получающих высокие оценки ото всех изданий и интернет–ресурсов, причем, количество этих игр росло с каждой неделей. На ней выходили такие хиты как The Legend of Zelda, Super Mario 3D, Pokemon и другие, что было популярно в Японии.
#
# 👀 Пользователи из Америки и Европы любят шутеры (более 40 млн проданных копий игр). Следом за ними Action и Sports. В Японии шутеры занимают лишь третью строчку (до 5 млн копий), с огромным отрывом от Action (свыше 20 млн) и Role-Playing (до 15 млн).
#
# 👀 Топ-2 рейтингов в Европе и Америке занимают "игры для взрослых от 17 лет" и для "всех возрастов". В Японии на первом месте - игры с рейтингом "подросткам от 13 лет", следом для "всех возрастов". Отсюда можно заключить, что рейтинг оказывает влияние на продажи в отдельном регионе
#
# 👀 Рейтинг ESRB в бОльшей степени влияет на европейских и американских игроков, чем на японских. В Японии, общая доля игр без оценок - больше, тк у них существует своя система оценок - CERO

# %% [markdown]
# ## Проверить гипотезы

# %% [markdown]
# ➮ средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# ➮ средние пользовательские рейтинги жанров Action и Sports разные
#
# Для этого:
# - задать самостоятельно пороговое значение alpha
# - пояснить как сформулировали нулевую и альтернативную гипотезы
# - пояснить какой критерий применили для проверки гипотез и почему

# %% [markdown]
# 👀 Чтобы оценить средние пользовательские рейтинги, необязательно брать весь датасет с информацией, который может оказаться устаревшим на текущий момент времени: достаточно взять небольшую, но репрезентативную часть данных за 2015-16 гг. Однако помним, что данные за 2016 г у нас непоные - в таком случае можем ориентироваться только на 2015. Для этого выведем отдельную переменную - `data_selection_2015`

# %%
data_selection_2015 = data.query('year_of_release == 2015')
data_selection_2015
# Out:
#                                                     name platform  \
# 31                             Call of Duty: Black Ops 3      PS4
# 77                                               FIFA 16      PS4
# 87                          Star Wars Battlefront (2015)      PS4
# 99                             Call of Duty: Black Ops 3     XOne
# 105                                            Fallout 4      PS4
# ...                                                  ...      ...
# 16326                        Saints Row: Gat out of Hell     XOne
# 16337  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
# 16339                                  Kiniro no Corda 3      3DS
# 16347                              Xblaze: Lost Memories      PSV
# 16391                Hakuoki: Reimeiroku - Omouhase Kara      PSV
#
#        year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 31                2015       Shooter      6.03      5.86      0.36
# ...

# %% [markdown]
# Далее выведем:
# - общее количество наблюдений
# - медиану и мат ожидание
# - стандартное отклонение

# %% [markdown]
# ### Распределение среднего количества пользовательских оценок по платформам XOne и PC

# %%
# информация для XOne 
data_selection_2015[data_selection_2015['platform'] =='XOne']['user_score'].describe()
# Out:
# count    55.000000
# mean      6.474545
# std       1.367103
# min       2.100000
# 25%       5.700000
# 50%       6.600000
# 75%       7.300000
# max       9.200000
# Name: user_score, dtype: float64

# %%
# информация для PC
data_selection_2015[data_selection_2015['platform'] =='PC']['user_score'].describe()
# Out:
# count    39.000000
# mean      6.294872
# std       1.813683
# min       1.400000
# 25%       5.200000
# 50%       7.100000
# 75%       7.600000
# max       9.300000
# Name: user_score, dtype: float64

# %%
data_selection_2015[data_selection_2015['platform'] =='XOne']['user_score'].hist(bins=10, alpha=0.4, color='green', legend=True)
data_selection_2015[data_selection_2015['platform'] =='PC']['user_score'].hist(bins=10, alpha=0.4, color='blue', legend=True);
plt.title('Распределение оценок по разным платформам')
plt.xlabel('Рейтинг')
plt.ylabel('Количество оценок')
plt.show()

# %% [markdown]
# 👀
# - Количество наблюдений у XOne больше, чем у PC (55 и 39 сообтветственно)
# - Среднее количество положительных оценок у PC чуть выше (7.1 против 6.6)
# - Среднее арифметическое (оно же мат. ожидание) у обоих платформ почти одинаковое - (XOne = 6.47, PC = 6.29)
# - Стандартное отклонение у обоих платформ схожи - (XOne = 1.37, PC = 1.81)

# %% [markdown]
# ### Распределение среднего количества пользовательских оценок по жанрам Action и Sports

# %%
# информация для Action 
data_selection_2015[data_selection_2015['genre'] =='Action']['user_score'].describe()
# Out:
# count    108.000000
# mean       6.941667
# std        1.229172
# min        2.500000
# 25%        6.500000
# 50%        7.150000
# 75%        7.700000
# max        9.000000
# Name: user_score, dtype: float64

# %%
# информация для Sports
data_selection_2015[data_selection_2015['genre'] =='Sports']['user_score'].describe()
# Out:
# count    45.000000
# mean      5.006667
# std       1.907450
# min       1.400000
# 25%       3.200000
# 50%       5.300000
# 75%       6.200000
# max       8.800000
# Name: user_score, dtype: float64

# %%
data_selection_2015[data_selection_2015['genre'] =='Action']['user_score'].hist(bins=10, alpha=1.0, color='lightblue', legend=True)
data_selection_2015[data_selection_2015['genre'] =='Sports']['user_score'].hist(bins=10, alpha=0.5, color='orange', legend=True);
plt.title('Распределение оценок по разным платформам')
plt.xlabel('Рейтинг')
plt.ylabel('Количество оценок')
plt.show()

# %% [markdown]
# 👀
# - Количество наблюдений у Action, больше, чем у Sports (108 / 45)
# - У Action выше среднее количество положительных оценок (7.15 / 5.3)
# - У Action выше среднее арифметическое (оно же мат. ожидание) - (6.94 / 5)
# - Стандартное отклонение у обоих жанров схожи (1.23 / 1.9)

# %% [markdown]
# ### Проверяем гипотезу: средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# - H₀ - средний рейтинг `user_score` Xbox One = средний рейтинг `user_score` PC
# - H₁ - средний рейтинг `user_score` Xbox One ≠ средний рейтинг `user_score` PC (двусторонняя альтернативная гипотеза)
#
# alpha = 0.05

# %% [markdown]
# В проверке гипотез нам поможет t-тест. Вспомним условия его применения:
# - ген. совокупности не должны зависеть друг от друга
# - выборочные средние должны быть нормально распределены (не обязательно)
# - дисперсии рассматриваемых совокупностей дб равны (но даже если не равны, тест редко ошибается)
#
# В нашем случае - все условия соблюдены

# %%
# Проверять будем через t-тест
xone_ttest = data_selection_2015[data_selection_2015['platform']=='XOne']['user_score']
pc_ttest = data_selection_2015[data_selection_2015['platform']=='PC']['user_score'] 

# results = вызов метода для проверки гипотезы
results = st.ttest_ind(xone_ttest.dropna(), pc_ttest.dropna(), equal_var=False)

# alpha = задайте значение уровня значимости
alpha = 0.05

# вывод значения p-value на экран
print('p-значение:', results.pvalue)

# условный оператор с выводом строки с ответом
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.6031609371064177
# Не получилось отвергнуть нулевую гипотезу

# %%
xone_ttest
# Out:
# 99       NaN
# 241      6.4
# 269      6.2
# 341      NaN
# 411      7.5
#         ...
# 15501    7.3
# 15608    7.2
# 15865    NaN
# 16262    7.1
# 16326    6.0
# Name: user_score, Length: 80, dtype: float64

# %% [markdown]
# 👀 Делаем вывод, что средние пользовательские рейтинги XOne и PC примерно равны

# %% [markdown]
# ### Проверяем гипотезу: средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# - H₀ - средний рейтинг `user_score` Action = средний рейтинг `user_score` Sports
# - H₁ - средний рейтинг `user_score` Action ≠ средний рейтинг `user_score`Sports (двусторонняя альтернативная гипотеза)
#
# alpha = 0.05

# %%
# Проверять будем через t-тест
action_ttest = data_selection_2015[data_selection_2015['genre']=='Action']['user_score']
sports_ttest = data_selection_2015[data_selection_2015['genre']=='Sports']['user_score'] 

# results = вызов метода для проверки гипотезы
results = st.ttest_ind(action_ttest.dropna(), sports_ttest.dropna(), equal_var=False)

# alpha = задайте значение уровня значимости
alpha = 0.05

# вывод значения p-value на экран
print('p-значение:', results.pvalue)

# условный оператор с выводом строки с ответом
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 4.1605525409314364e-08
# Отвергаем нулевую гипотезу

# %%
action_ttest
# Out:
# 230      8.1
# 304      7.6
# 388      8.2
# 394      6.8
# 404      NaN
#         ...
# 16283    NaN
# 16307    NaN
# 16311    NaN
# 16326    6.0
# 16391    NaN
# Name: user_score, Length: 253, dtype: float64

# %% [markdown]
# 👀 Делаем вывод, что средние пользовательские рейтинги жанров Action и Sports различаются

# %% [markdown]
# ### Вывод по исследованию гипотез

# %% [markdown]
# Проверили гипотезы по функции ttest_ind, вычисляющей t-тест двух независимых выборок:
#
# - Гипотеза: "Средние пользовательские рейтинги платформ Xbox one и PC одинаковые". Не получилось отвергнуть нулевую гипотезу
# - Гипотеза: "Средние пользовательские рейтинги жанров Action и Sports разные". Отвергаем нулевую гипотезу

# %% [markdown]
# ## Общие выводы по исследованию

# %% [markdown]
# Перед анализом мы подготовили наши данные:
# - привели названия столбцов к нижнему регистру
# - привели к правильным типам данных необходимые столбцы
# - проверили на дубликаты и пропуски. Заменили пропуски значениями, где это возможно. Определили, что аббревиатура TBD значит to be determined = данные были нарочно не заполнены. Поэтому заменили tbd на NaN для проведения дальнейшего анализа. Пропуски в признаке рейтинга заполнили заглушками
# - выделили суммарные продажи во всех регионах в отдельный столбец
#
# Проведя анализ, мы выявили, что:
# - до 90-х г выходило менее 100 игр ежегодно, тк в то время компьютерные технологии были развиты не так сильно. С 90-х до 2008 индустрия начала набирать обороты. Пик количества выходов игр - 2008-09 гг, далее снижение с 2012 года (вероятно из-за активного развития рынка мобильных приложений)
#
# - за весь период консольных приставок самые популярные оказались: PS2, X360, PS3, Wii, DS, PS4
#
# - средняя продолжительность жизни игровой приставки составляет порядка 7-10 лет. Самый пик продаж наступает примерно через 5 лет после выпуска консоли. Бросается в глаза самая долгоживущая из платформ - РС
#
# - топы платформ по общему кол-ву продаж игр постепенно начали заменяться другими, более современными версиями (но их показатели скромнее их предшественников)
#
# - чтобы не учитывать отжившие тренды в такой быстроменяющейся индустрии как видеоигры, отбросили данные до 2000 г, чтобы иметь более репрезентативную общую выборку для дальнейшего анализа и сравнили их с показателями за 2 последних года (2015-16 гг)
#
# - у платформ-лидеров наблюдается взаимосвязь между продажами и оценками критиков. Пользовательские же оценки почти не играют значимой роли. Это значит, что для людей мнение критиков важнее мнения других пользователей (исключение - старенькие платформы, где мнение пользователей иногда превалирует). Самый популярный жанр - 'Shooter', не популярные - 'Adventure' и 'Puzzle'
#
# После мы составили портреты пользователей каждого региона за 2015-16 гг:
# - пользователи из Америки и Европы отдают предпочтение PS4 и XOne. Причем XOne в Европе гораздо менее популярна, чем в Америке.
# Японцы отдают предпочтение Nintendo 3DS (PS4 почти вполовину менее популярна, а XOne вообще не вошел в топ-5). Отсюда следует, что бОльшую долю в продажах в Японии занимают исключительно национальные платформы, которые продаются полностью или преимущественно в Японии
# - пользователи из Америки и Европы любят шутеры (более 40 млн проданных копий игр). Следом за ними Action и Sports. В Японии шутеры занимают лишь третью строчку (до 5 млн копий), с огромным отрывом от Action (свыше 20 млн) и Role-Playing (до 15 млн).
# - топ-2 рейтингов в Европе и Америке занимают "игры для взрослых от 17 лет" и для "всех возрастов". В Японии на первом месте - игры с рейтингом "подросткам от 13 лет", следом для "всех возрастов". Отсюда можно заключить, что рейтинг оказывает влияние на продажи в отдельном регионе
# - рейтинг ESRB в бОльшей степени влияет на европейских и американских игроков, чем на японских. В Японии, общая доля игр без оценок - больше, тк у них существует своя местная система оценок - CERO
#
# Проверили гипотезы:
# - средние пользовательские рейтинги платформ Xbox one и PC одинаковые - не получилось отвергнуть нулевую гипотезу
# - средние пользовательские рейтинги жанров Action и Sports разные - отвергаем нулевую гипотезу
#
# Таким образом проведенное исследование позволило определить перспективные рынки, сегменты и локации для планирования продаж и продвижения в 2017 году, а также обосновать предложенный выбор.
#
# В качестве рекомендации к исследованию: можно добавить сумму сборов / бюджетов игр, чтобы видеть более мелкие или крупные проекты, которые в будущем могут принести магазину выручку = посмотреть какие игры в каких странах собрали больше "проката", чтобы нацелиться именно на них
